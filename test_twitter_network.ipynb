# %%
import numpy as np
import pandas as pd
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
edges = pd.read_csv("data/network/ego-twitter/ego-twitter.edges", skiprows=2)

# %%
edge_list = list(zip(edges["1"].tolist(), edges["2"].tolist()))

# %%
G = nx.Graph()

# %%
G.add_edges_from(edge_list[:200])

# %% [markdown]
# Let's us now try to find the node with the largest betweenness centrality

# %%
def find_highest_between_centraility(G):
    # Get the betweenness centrality
    centralities = nx.betweenness_centrality(G)
    # Now get the highest value of centrality
    max_centrality = max(centralities.values())
    
    max_nodes = filter(lambda k: )
# Out:
#   File "<ipython-input-7-e9b87092a5f5>", line 7
#     max_nodes = filter(lambda k: )
#                                  ^
# SyntaxError: invalid syntax

# %%
bet_central = nx.betweenness_centrality(G)

# %%
nx.draw_kamada_kawai(G, with_labels=True)

# %%
max(bet_central.values())
# Out:
# 0.05169775227164036

# %%
filter(lamda x:x)
